# %% [markdown]
# ![9ec16c91034815934c0eda310ef412e1.PNG](attachment:9ec16c91034815934c0eda310ef412e1.PNG)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import timeit

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
from torchvision import datasets, transforms

# %%
# %pip install matplotlib torch torchvision seaborn
# Out:
# Requirement already satisfied: matplotlib in /Users/leon/miniforge3/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: torch in /Users/leon/miniforge3/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: torchvision in /Users/leon/miniforge3/lib/python3.10/site-packages (0.18.1)
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/leon/miniforge3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: filelock in /Users/leon/miniforge3/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/leon/miniforge3/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /Users/leon/miniforge3/lib/python3.10/site-packages (from torch) (1.13.0)
# Requirement already satisfied: networkx in /Users/leon/miniforge3/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/leon/miniforge3/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/leon/miniforge3/lib/python3.10/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: pandas>=1.2 in /Users/leon/miniforge3/lib/python3.10/site-packages/pandas-2.0.3-py3.10-macosx-11.0-arm64.egg (from seaborn) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/leon/miniforge3/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/leon/miniforge3/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /Users/leon/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/leon/miniforge3/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/leon/miniforge3/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5), (0.5))])
train_data = datasets.FashionMNIST(root=".", download=False, train = True, transform= transform)
test_data = datasets.FashionMNIST(root=".", download=False, train = False, transform= transform)

# %%
iterator = iter(train_data)
image, label = next(iterator)


plt.figure(figsize = (9, 3))
for i in range(8):
    plt.subplot(2,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(image.permute(1,2,0).squeeze(), cmap = "gray")
    plt.title(train_data.classes[label])
    image,label = next(iterator)
plt.tight_layout(h_pad=2)
plt.show()

# %%
import numpy as np

class configs(object):
    learning_rates=0.001
    n_iters=1000
    batch_size=100
    epochs = 
training_configs = configs()

batchsize = training_configs.batch_size
torch.manual_seed(0)

# Loaders for data with normalization
train_data_loader = torch.utils.data.DataLoader(train_data, shuffle = True, batch_size = batchsize, num_workers = 2)
test_data_loader = torch.utils.data.DataLoader(test_data, shuffle = False, batch_size = batchsize, num_workers = 2)
# Out:
#   Cell In[37], line 7
#     epochs =
#              ^
# SyntaxError: invalid syntax

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

class LogisticRegression(torch.nn.Module):
    def __init__(self, configs):
        super(LogisticRegression, self).__init__()
        self.losses = []
        self.lr = configs.learning_rates
        self.n_iters = configs.n_iters
        self.batch_size = configs.batch_size
        self.linear = torch.nn.Linear(784,10) # 784 is used because each Fashion-MNIST PIL image has 28x28 pixel(data points)
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self,x):
        pred = self.linear(x)
        return self.softmax(pred)

# %%
criterion1 = nn.CrossEntropyLoss()
model = LogisticRegression(configs)
optimiser = optim.SGD(model.parameters(), lr=0.001, momentum=0.9) 
epochs = 1
print("training starts\n")

reg_loss = nn.L1Loss()
start = timeit.default_timer() # Starting the timer
for iteration in range(epochs):
    losses = []
    for i,j in enumerate(train_data_loader):
        image, label = j # loading a batch of input train data
        optimiser.zero_grad()
        predictions = model(image.view(-1, 784))
        loss = criteria(predictions, label)

        for params in LogReg1.parameters():
            temp += reg_loss(params, target = torch.zeros_like(params))
            loss += 0.00005*reg_loss(params, target = torch.zeros_like(params))

        loss.backward() # back propogating the losses
        optimiser.step()

        losses += loss.item()
        if i%2000 == 0:
            print('epoch:',iteration,'\t','instance:',i,'\t','Avg loss:',sum(losses[-2000:])/2000)

print("Training is done!\n")

# Determining the time taken to train the model
total_time = timeit.default_timer() - start
print("Model training time:", total_time) 

# # Determining the learnable parameters in the model
# no_of_para = 0
# for i in list(model.parameters()):
#     no_of_para += torch.tensor(i.size()).prod().item()
# print("No of Model parameters:",no_of_para)  

# return(total_time, no_of_para)
# # Testing the Logistic regression model on train data(part a)
# data = "Prediction accuracy for training data:"
# _,_, train_acc_LogReg1 = testing_fn(LogReg1, train_data_T_loader, data)

# # Testing the Logistic regression model on test data(part a)
# data = "Prediction accuracy for test data:"
# actual, prediction, test_acc_LogReg1 = testing_fn(LogReg1, test_data_T_loader, data)
# title = "Confusion matrix for predictions on test data"
# con_matrix(actual, prediction, title)
# Out:
# training starts
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 11
#       9 for iteration in range(epochs):
#      10     losses = []
# ---> 11     for i,j in enumerate(train_data_loader):
#      12         image, label = j # loading a batch of input train data
#      13         optimiser.zero_grad()
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1346, in _MultiProcessingDataLoaderIter._next_data(self)
#    1344 else:
#    1345     del self._task_info[idx]
# -> 1346     return self._process_data(data)
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1372, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1370 self._try_put_index()
#    1371 if isinstance(data, ExceptionWrapper):
# -> 1372     data.reraise()
#    1373 return data
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/_utils.py:705, in ExceptionWrapper.reraise(self)
#     701 except TypeError:
#     702     # If the exception takes multiple arguments, don't try to
#     703     # instantiate since we don't know how to
#     704     raise RuntimeError(msg) from None
# --> 705 raise exception
#
# TypeError: Caught TypeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/Users/leon/miniforge3/lib/python3.10/site-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#   File "/Users/leon/miniforge3/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     return self.collate_fn(data)
#   File "/Users/leon/miniforge3/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py", line 316, in default_collate
#     return collate(batch, collate_fn_map=default_collate_fn_map)
#   File "/Users/leon/miniforge3/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py", line 173, in collate
#     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#   File "/Users/leon/miniforge3/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py", line 173, in <listcomp>
#     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#   File "/Users/leon/miniforge3/lib/python3.10/site-packages/torch/utils/data/_utils/collate.py", line 191, in collate
#     raise TypeError(default_collate_err_msg_format.format(elem_type))
# TypeError: default_collate: batch must contain tensors, numpy arrays, numbers, dicts or lists; found <class 'PIL.Image.Image'>
